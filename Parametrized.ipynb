# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/FinalProject
IMAGE_PATH='images/'
# Out:
# /content/drive/.shortcut-targets-by-id/1bXi9uXJlRd3MyzEZQERAL3lIrx8FkT26/FinalProject

# %% [markdown]
# # Bifurcation
# Changes in the qualitative behavior of the dynamical system over changes of their <b>parameters</b> are called <b>bifurcations</b>. Parameters differ depending on a domain. i.e. • Desired speed for individuals • Distance to obstacles • Width of doors • Number of pedestrians in a room can be parameters in crowd dynamics.

# %%
# %load_ext autoreload
# %autoreload 2
# !pip install pytorch-lightning==0.7.6 > /dev/null
import pytorch_lightning as pl
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
import torch.nn as nn
import torch.nn.functional as F
import math
from scipy.integrate import solve_ivp
from util import *

# %matplotlib inline
#plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# cuda
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Generate data for training
# We want to learn bifurcation given in Exercise 3.
#
# $\dot{x_1} = \alpha x_1 - x_2 - x_1(x_1^2 + x_2^2)$, <br />
# $\dot{x_2} = x_1 + \alpha x_2 - x_2(x_1^2 + x_2^2)$,
# <br />
# Therefore, we generate ground truth data for this dynamical system with $ scipy.integrate.solve_ivp$ for initial point $(0,2)$
#
# The dataset generated is saved into a file called "data_tensor.pt"
#
# If there already exists a dataset created by passing the function False we use the existing dataset in the "data_tensor.pt" file.

# %%
def get_data(create = False):
  if create == True:
    # LOAD FROM DATASET. data is generated in cuda from. use "map_location=torch.device('cpu')" if you want to load into cpu
    '''
      alphas are between -2 and 2 in the generated dataset.
    '''
    BIFURCATION_DATASET = generate_data().to(device) #torch.load('BIFURCATION_DATASET_n_250_dt_100.pt', map_location=torch.device('cpu')) # 
    #BIFURCATION_DATASET = BIFURCATION_DATASET.to('cpu')

    #Save the dataset into a file so that you dont have to generate it again:
    torch.save(BIFURCATION_DATASET, "data_tensor.pt")
  else:
    BIFURCATION_DATASET = torch.load("data_tensor_new_small.pt")
  return BIFURCATION_DATASET

# %%
BIFURCATION_DATASET = get_data(create=False)

# %%
# BIFURCATION_DATASET NX3
# PLOT ALL TRAJECTORIES
plot_generated_data(BIFURCATION_DATASET.cpu())

# %% [markdown]
# # Euler Class creation
#
# Create the Euler class with the given dimensions.
# Several Important factors change on the output has not been analyzed. This includes:
#
#
# *   Larger than 256 hidden dimension
# *   Usage of bias in hidden layers
# *   Number of hidden layers, we only know that it performs better with more than 2 hidden layers.

# %%
class Eueler(nn.Module):
    def __init__(self, input_size=3, output_size=2, hidden_size = 64):
        """
        param D: dimension of state variable X
        param H: hiddensize
        """
        super(Eueler, self).__init__()
        self.M = input_size
        self.D = output_size
        self.H = hidden_size

        self.linear_input = nn.Linear(self.M, self.H,bias=True)
        self.linear_hidden1 = nn.Linear(self.H, self.H,bias=True)
        self.linear_hidden2 = nn.Linear(self.H, self.H,bias=True)
        self.linear_hidden3 = nn.Linear(self.H, self.H,bias=True)
        self.linear_hidden4 = nn.Linear(self.H, self.H,bias=True)
        self.linear_output = nn.Linear(self.H, self.D,bias=True)
        
    def forward(self, X, dt):
        """
        param X: (N,M) Initial points with correspoding operating parameters
        param t: Delta(t)
        """

        # Black box
        f = self.linear_input(X)
        #for k in range(3):
        #  f = self.linear_hidden(F.relu(f))
        f = self.linear_hidden1(F.relu(f))
        f = self.linear_hidden2(F.relu(f))
        f = self.linear_hidden3(F.relu(f))
        f = self.linear_hidden4(F.relu(f))
        f = self.linear_output(f)

        # Integrator
        x_1 = X[:,:self.D] + f * (torch.from_numpy(np.ones_like(f.shape)) * dt).to(device)

        return f, x_1

# %% [markdown]
# # Runge Kutta
#
# Runge kutta model is pretty similar (in this first prototype identical) to the euler model. This is because the models predict different things. This model results only indiretly effects the next point. The result here is what we use for each "k" values calculation. It is what hf(input, parameters) is. Therefore this will be called 4 times for each prediction. (so we might want to keep the number of parameters low initially)

# %%
class RungeKutta(nn.Module):
    def __init__(self, input_size=3, output_size=2, hidden_size = 64):
        """
        y=xAT

        param D: dimension of X
        param H: hiddensize
        """
        super(RungeKutta, self).__init__()
        self.M = input_size
        self.D = output_size
        self.H = hidden_size

        self.linear_input = nn.Linear(self.M, self.H,bias=True)
        self.linear_hidden1 = nn.Linear(self.H, self.H,bias=True)
        self.linear_hidden2 = nn.Linear(self.H, self.H,bias=True)
        self.linear_hidden3 = nn.Linear(self.H, self.H,bias=True)
        self.linear_hidden4 = nn.Linear(self.H, self.H,bias=True)
        self.linear_output = nn.Linear(self.H, self.D,bias=True)

    def forward(self, X, dt):
        """
        param x_0: (N,D) Initial points
        param t: Delta(t)
        """
        # Black box
        def black_box(X):
          f = self.linear_input(X)
          f = self.linear_hidden1(F.relu(f))
          f = self.linear_hidden2(F.relu(f))
          f = self.linear_hidden3(F.relu(f))
          f = self.linear_hidden4(F.relu(f))
          f = self.linear_output(f)

          return f

        f = black_box(X)  # NxM => NxD
        y_pred = f
        h = (torch.from_numpy(np.ones_like(y_pred.shape)) * dt).to(device)

        k1 = torch.zeros_like(X).to(device)  # to add k1 onto x, they need to be same size though
        k1[:, :y_pred.shape[1]] = y_pred * h
        # Add it to x and get another prediction, this time for k2
        y_pred = black_box(X + k1 / 2)  # NxM => NxD
        k2 = torch.zeros_like(X).to(device)  # to add k1 onto x, they need to be same size though
        k2[:, :y_pred.shape[1]] = y_pred * h
        # k3:
        y_pred = black_box(X + k2 / 2)  # NxM => NxD
        k3 = torch.zeros_like(X).to(device)  # to add k1 onto x, they need to be same size though
        k3[:, :y_pred.shape[1]] = y_pred * h
        # k4:
        y_pred = black_box(X + k3).to(device)  # NxM => NxD
        k4 = torch.zeros_like(X)  # to add k1 onto x, they need to be same size though
        k4[:, :y_pred.shape[1]] = y_pred * h

        x_1 = X[:, :self.D] + 1 / 6 * (k1[:, :self.D] + 2 * k2[:, :self.D] + 2 * k3[:, :self.D] + k4[:, :self.D])


        return f, x_1

# %%
# https://pytorch.org/tutorials/beginner/pytorch_with_examples.html


def euler_model(input_size=3,output_size=2,hidden_size=128):
  model = Eueler(input_size=input_size,output_size=output_size,hidden_size=hidden_size).to(device)
  loss_fn = nn.MSELoss()
  learning_rate = 1e-4
  optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
  return model, loss_fn, optimizer

def rungekutta_model(input_size=3,output_size=2,hidden_size=128):
  model = RungeKutta(input_size=input_size,output_size=output_size,hidden_size=hidden_size).to(device)
  loss_fn = nn.MSELoss()
  learning_rate = 1e-4
  optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
  return model, loss_fn, optimizer

# %% [markdown]
# # These are two functions that can be used for both Euler method and Runge Kutta.
#
# The prediction function, which creates a meshgrid between -2 and 2, hence if you are predicting values not in range be careful with this part!
#
# The Phase portrait plot function, which is actually used by the function phase_check()

# %%
def get_predictions(alpha,model):
  x = np.arange(-2, 2, 0.01)
  x1, x2 = np.meshgrid(x, x)
  X_0 = np.vstack((x1.flatten(), x2.flatten())).T

  A = np.array([[alpha]*len(X_0)]).T
  X = np.append(X_0, A, axis=1)
  X = torch.from_numpy(X).float().to(device) # use np.column_stack([X_0, alpha]) instead

  dt = torch.tensor(0.1).to(device).float()
  f, _ = model(X, dt)
  f = f.cpu().detach().numpy()
  y1 = f[:,0].reshape(x1.shape)
  y2 = f[:,1].reshape(x2.shape)

  return (x1, x2, y1, y2)


def plot_phase_portrait(ax, pred, alpha):
  ax.streamplot(*pred, color='dodgerblue', linewidth=1)
  ax.set_title("alpha = {}".format(alpha))
  ax.set_xlim([-2,2])
  ax.set_ylim([-2,2])

def single_trajectory(model):
  pass

# %% [markdown]
# # Training function for Euler
# To fix the memory issue:
# 1) Torch no grad for validation
# 2)before validation torch.eval()
# PS: the validation does not seem to have any no batch or anything, might be good to have a more structured validation. (so that we can implement torch.no_grad and torch.eval() more clearly)
# https://www.kaggle.com/c/bengaliai-cv19/discussion/133119

# %%
def plot_loss_curve(val_loss_arr):
  plt.plot(val_loss_arr)
  plt.xlabel("Number of epoch")
  plt.ylabel("Loss")
  plt.show()

# %%
"""
FULL TRAINING PROCEDURE FOR EULER
ASSUME WE HAVE `BIFURCATION_DATASET`
ALL OTHER OPERATIONS WILL BE DONE IN THIS BLOCK FOR TRAINING
"""
def train_euler(BIFURCATION_DATASET, epochs = 1000, H = 128):
  import time
  print("BIFURCATION_DATASET.shape {}".format(BIFURCATION_DATASET.shape))
  N = len(BIFURCATION_DATASET) # Size of dataset

  M=3   # input_size
  D=2   # output_size
  H=H # hidden_size
  model, loss_fn, optimizer = euler_model(M, D, H) # defaults: input_size=3, output_size=2, hidden_size=128

  num_train, num_val, num_test = int(N * 0.6), int(N * 0.3), int(N * 0.1)

  np.random.seed(0)
  indices = np.random.permutation(N)
  train_idx, val_idx, test_idx = indices[:num_train], indices[num_train:num_train + num_val], indices[num_train + num_val:]
  #print("BIFURCATION_DATASET.shape {}".format(BIFURCATION_DATASET.shape))
  batch_size = 32
  batch_num = math.floor(N/batch_size)
  #print("train_idx {}".format(train_idx))
  batched_train_idxs = np.array_split(train_idx, batch_num)
  #print("batched_train_idxs.shape {}".format(batched_train_idxs))
  X = BIFURCATION_DATASET[:,:M]
  X_1 = BIFURCATION_DATASET[:,M:]
  
  val_loss_arr = []
  
  dt = torch.tensor(0.1).to(device).float()
  for t in range(epochs):
    train_epoch_loss = 0.0
    seconds = time.time()
    for batch_idx in batched_train_idxs:
      x_0_with_alpha = X[batch_idx].float()
      x_1 = X_1[batch_idx].float()

      _, y_pred = model(x_0_with_alpha, dt) # NxM => NxD

      # Compute and print loss.
      loss = loss_fn(y_pred, x_1)
      train_epoch_loss += loss

      optimizer.zero_grad()

      loss.backward()

      optimizer.step()

    model.eval()
    with torch.no_grad():
      train_epoch_loss /= len(train_idx)
      _, pred = model(X[val_idx].float(), dt)
      validation_loss = loss_fn(pred, X_1[val_idx].float())
      val_loss_arr.append(validation_loss)
      print('(Epoch %d / %d, seconds: %d) train loss: %f validation loss: %f' % (t + 1, epochs, (time.time()-seconds), train_epoch_loss, validation_loss))
    model.train()
  plot_loss_curve(val_loss_arr)
  return model

# %% [markdown]
# # Runge Kutta:
#
# Runge kutta has the following architecture:
#
# <img width="800" src="https://drive.google.com/file/d/1tpBHXdeyZNhurTlL-AXyweBwWU65pxSb/view?usp=sharing" />
#
# So we will call the same network multiple times, each by adding onto x data the previous k. At the end we will sum them all to get the ground truth.

# %%
"""
FULL TRAINING PROCEDURE FOR RUNGE-KUTTA
ASSUME WE HAVE `BIFURCATION_DATASET`
ALL OTHER OPERATIONS WILL BE DONE IN THIS BLOCK FOR TRAINING
"""
def train_rungekutta(BIFURCATION_DATASET, epochs = 1000, H = 128):
  import time
  print("BIFURCATION_DATASET.shape {}".format(BIFURCATION_DATASET.shape))
  N = len(BIFURCATION_DATASET) # Size of dataset

  M=3   # input_size
  D=2   # output_size
  H=H # hidden_size
  model, loss_fn, optimizer = rungekutta_model(M, D, H) # defaults: input_size=3, output_size=2, hidden_size=128

  num_train, num_val, num_test = int(N * 0.6), int(N * 0.3), int(N * 0.1)

  np.random.seed(0)
  indices = np.random.permutation(N)
  train_idx, val_idx, test_idx = indices[:num_train], indices[num_train:num_train + num_val], indices[num_train + num_val:]
  #print("BIFURCATION_DATASET.shape {}".format(BIFURCATION_DATASET.shape))
  batch_size = 32
  batch_num = math.floor(N/batch_size)
  #print("train_idx {}".format(train_idx))
  batched_train_idxs = np.array_split(train_idx, batch_num)
  #print("batched_train_idxs.shape {}".format(batched_train_idxs))
  X = BIFURCATION_DATASET[:,:M]
  X_1 = BIFURCATION_DATASET[:,M:]
  val_loss_arr = []

  dt = torch.tensor(0.1).to(device).float()
  for t in range(epochs):
    train_epoch_loss = 0.0
    seconds = time.time()
    for batch_idx in batched_train_idxs:
      x_0_with_alpha = X[batch_idx].float()
      x_1 = X_1[batch_idx].float()

      #find k1,
      f, prediction = model(x_0_with_alpha, dt) # NxM => NxD

      # Compute and print loss.
      loss = loss_fn(prediction, x_1)
      train_epoch_loss += loss

      optimizer.zero_grad()

      loss.backward()

      optimizer.step()

    model.eval()
    with torch.no_grad():
      train_epoch_loss /= len(train_idx)
      _, pred = model(X[val_idx].float(), dt)
      validation_loss = loss_fn(pred, X_1[val_idx].float())
      val_loss_arr.append(validation_loss)
      print('(Epoch %d / %d, seconds: %d) train loss: %f validation loss: %f' % (t + 1, epochs, (time.time()-seconds), train_epoch_loss, validation_loss))
    model.train()
  plot_loss_curve(val_loss_arr)
  return model

# %%
def phase_check_rungekutta(model):
  #alphas = np.random.uniform(-2,2, 10)
  alphas = [-1.0, 0.0, 1.0, 2.0]
  fig, axs = plt.subplots(1,len(alphas), figsize=(16,4))

  for i, a in enumerate(alphas):
    x = np.arange(-2, 2, 0.01)
    x1, x2 = np.meshgrid(x, x)
    X_0 = np.vstack((x1.flatten(), x2.flatten())).T

    A = np.array([[a]*len(X_0)]).T
    X = np.append(X_0, A, axis=1)
    X = torch.from_numpy(X).float().to(device) # use np.column_stack([X_0, alpha]) instead

    dt = torch.tensor(0.1).to(device).float()

    f, y_pred = model(X, dt) # NxM => NxD
    
    y1 = f[:,0]
    y2 = f[:,1]

    y1 = (y1.cpu()).detach().numpy()
    y2 = (y2.cpu()).detach().numpy()
    #x1.to(device)
    #x2.to(device)
    y1 = y1.reshape(x1.shape)
    y2 = y2.reshape(x2.shape)
    pred = (x1, x2, y1, y2)
    plot_phase_portrait(axs[i], pred, a)

  plt.xlabel("x1")
  plt.ylabel("x2")
  plt.show()

# %%
#alphas = [-1.0, 0.0, 1.0, 2.0]
def phase_check(model):
  #alphas = np.random.uniform(-2,2, 10)
  alphas = [-1.0, 0.0, 1.0, 2.0]
  fig, axs = plt.subplots(1,len(alphas), figsize=(16,4))

  for i, a in enumerate(alphas):
    pred = get_predictions(a, model)
    x1, x2, y1, y2 = pred
    plot_phase_portrait(axs[i], pred, a)

  plt.xlabel("x1")
  plt.ylabel("x2")
  plt.show()

# %% [markdown]
# # Train Runge-kutta

# %%
trained_model_runge = train_rungekutta(BIFURCATION_DATASET, 50, 128)
torch.save(trained_model_runge.state_dict(),'./rungekuttamodel.pt')
# Out:
# BIFURCATION_DATASET.shape torch.Size([645605, 5])
# (Epoch 1 / 50, seconds: 113) train loss: 0.000108 validation loss: 0.000890
# (Epoch 2 / 50, seconds: 112) train loss: 0.000046 validation loss: 0.000867
# (Epoch 3 / 50, seconds: 112) train loss: 0.000043 validation loss: 0.000851
# (Epoch 4 / 50, seconds: 112) train loss: 0.000040 validation loss: 0.000825
# (Epoch 5 / 50, seconds: 112) train loss: 0.000039 validation loss: 0.000796
# (Epoch 6 / 50, seconds: 112) train loss: 0.000038 validation loss: 0.000761
# (Epoch 7 / 50, seconds: 112) train loss: 0.000037 validation loss: 0.000727
# (Epoch 8 / 50, seconds: 112) train loss: 0.000036 validation loss: 0.000706
# (Epoch 9 / 50, seconds: 113) train loss: 0.000035 validation loss: 0.000691
# (Epoch 10 / 50, seconds: 112) train loss: 0.000035 validation loss: 0.000670
# (Epoch 11 / 50, seconds: 112) train loss: 0.000034 validation loss: 0.000661
# (Epoch 12 / 50, seconds: 113) train loss: 0.000034 validation loss: 0.000651
# (Epoch 13 / 50, seconds: 112) train loss: 0.000034 validation loss: 0.000643
# (Epoch 14 / 50, seconds: 112) train loss: 0.000033 validation loss: 0.000637
# (Epoch 15 / 50, seconds: 112) train loss: 0.000033 validation loss: 0.000627
# (Epoch 16 / 50, seconds: 112) train loss: 0.000033 validation loss: 0.000624
# (Epoch 17 / 50, seconds: 112) train loss: 0.000032 validation loss: 0.000615
# (Epoch 18 / 50, seconds: 113) train loss: 0.000032 validation loss: 0.000608
# (Epoch 19 / 50, seconds: 112) train loss: 0.000032 validation loss: 0.000603
# (Epoch 20 / 50, seconds: 113) train loss: 0.000031 validation loss: 0.000597
# (Epoch 21 / 50, seconds: 112) train loss: 0.000031 validation loss: 0.000594
# (Epoch 22 / 50, seconds: 112) train loss: 0.000031 validation loss: 0.000589
# (Epoch 23 / 50, seconds: 112) train loss: 0.000031 validation loss: 0.000585
# (Epoch 24 / 50, seconds: 113) train loss: 0.000031 validation loss: 0.000580
# (Epoch 25 / 50, seconds: 112) train loss: 0.000030 validation loss: 0.000576
# (Epoch 26 / 50, seconds: 113) train loss: 0.000030 validation loss: 0.000571
# (Epoch 27 / 50, seconds: 113) train loss: 0.000030 validation loss: 0.000565
# (Epoch 28 / 50, seconds: 112) train loss: 0.000030 validation loss: 0.000564
# (Epoch 29 / 50, seconds: 113) train loss: 0.000030 validation loss: 0.000557
# (Epoch 30 / 50, seconds: 113) train loss: 0.000029 validation loss: 0.000557
# (Epoch 31 / 50, seconds: 113) train loss: 0.000029 validation loss: 0.000553
# (Epoch 32 / 50, seconds: 113) train loss: 0.000029 validation loss: 0.000548
# (Epoch 33 / 50, seconds: 112) train loss: 0.000029 validation loss: 0.000547
# (Epoch 34 / 50, seconds: 113) train loss: 0.000029 validation loss: 0.000542
# (Epoch 35 / 50, seconds: 112) train loss: 0.000029 validation loss: 0.000539
# (Epoch 36 / 50, seconds: 112) train loss: 0.000028 validation loss: 0.000535
# (Epoch 37 / 50, seconds: 113) train loss: 0.000028 validation loss: 0.000533
# (Epoch 38 / 50, seconds: 112) train loss: 0.000028 validation loss: 0.000543
# (Epoch 39 / 50, seconds: 113) train loss: 0.000028 validation loss: 0.000542
# (Epoch 40 / 50, seconds: 113) train loss: 0.000028 validation loss: 0.000529
# (Epoch 41 / 50, seconds: 112) train loss: 0.000028 validation loss: 0.000531
# (Epoch 42 / 50, seconds: 113) train loss: 0.000028 validation loss: 0.000532
# (Epoch 43 / 50, seconds: 112) train loss: 0.000027 validation loss: 0.000545
# (Epoch 44 / 50, seconds: 112) train loss: 0.000027 validation loss: 0.000527
# (Epoch 45 / 50, seconds: 113) train loss: 0.000027 validation loss: 0.000554
# (Epoch 46 / 50, seconds: 113) train loss: 0.000027 validation loss: 0.000521
# (Epoch 47 / 50, seconds: 112) train loss: 0.000027 validation loss: 0.000534
# (Epoch 48 / 50, seconds: 113) train loss: 0.000027 validation loss: 0.000535
# (Epoch 49 / 50, seconds: 112) train loss: 0.000027 validation loss: 0.000548
# (Epoch 50 / 50, seconds: 113) train loss: 0.000027 validation loss: 0.000522

# %% [markdown]
# # Phase check Runge Kutta

# %%
phase_check_rungekutta(trained_model_runge)

# %%
trained_model_runge_2 = train_rungekutta(BIFURCATION_DATASET, 100, 128)
torch.save(trained_model_runge_2.state_dict(),'./rungekuttamodel_100epoch.pt')
# Out:
# BIFURCATION_DATASET.shape torch.Size([645605, 5])
# (Epoch 1 / 100, seconds: 190) train loss: 0.000110 validation loss: 0.000895
# (Epoch 2 / 100, seconds: 188) train loss: 0.000045 validation loss: 0.000857
# (Epoch 3 / 100, seconds: 188) train loss: 0.000042 validation loss: 0.000833
# (Epoch 4 / 100, seconds: 189) train loss: 0.000039 validation loss: 0.000803
# (Epoch 5 / 100, seconds: 190) train loss: 0.000038 validation loss: 0.000776
# (Epoch 6 / 100, seconds: 190) train loss: 0.000037 validation loss: 0.000745
# (Epoch 7 / 100, seconds: 190) train loss: 0.000036 validation loss: 0.000728
# (Epoch 8 / 100, seconds: 190) train loss: 0.000035 validation loss: 0.000708
# (Epoch 9 / 100, seconds: 188) train loss: 0.000035 validation loss: 0.000695
# (Epoch 10 / 100, seconds: 190) train loss: 0.000034 validation loss: 0.000683
# (Epoch 11 / 100, seconds: 190) train loss: 0.000034 validation loss: 0.000667
# (Epoch 12 / 100, seconds: 190) train loss: 0.000034 validation loss: 0.000662
# (Epoch 13 / 100, seconds: 198) train loss: 0.000033 validation loss: 0.000652
# (Epoch 14 / 100, seconds: 201) train loss: 0.000033 validation loss: 0.000647
# (Epoch 15 / 100, seconds: 199) train loss: 0.000033 validation loss: 0.000640
# (Epoch 16 / 100, seconds: 189) train loss: 0.000032 validation loss: 0.000632
# (Epoch 17 / 100, seconds: 188) train loss: 0.000032 validation loss: 0.000624
# (Epoch 18 / 100, seconds: 188) train loss: 0.000032 validation loss: 0.000617
# (Epoch 19 / 100, seconds: 189) train loss: 0.000032 validation loss: 0.000613
# (Epoch 20 / 100, seconds: 190) train loss: 0.000031 validation loss: 0.000603
# (Epoch 21 / 100, seconds: 190) train loss: 0.000031 validation loss: 0.000593
# (Epoch 22 / 100, seconds: 190) train loss: 0.000031 validation loss: 0.000588
# (Epoch 23 / 100, seconds: 189) train loss: 0.000031 validation loss: 0.000587
# (Epoch 24 / 100, seconds: 189) train loss: 0.000030 validation loss: 0.000583
# (Epoch 25 / 100, seconds: 190) train loss: 0.000030 validation loss: 0.000579
# (Epoch 26 / 100, seconds: 187) train loss: 0.000030 validation loss: 0.000574
# (Epoch 27 / 100, seconds: 189) train loss: 0.000030 validation loss: 0.000575
# (Epoch 28 / 100, seconds: 188) train loss: 0.000030 validation loss: 0.000568
# (Epoch 29 / 100, seconds: 188) train loss: 0.000030 validation loss: 0.000570
# (Epoch 30 / 100, seconds: 188) train loss: 0.000029 validation loss: 0.000564
# (Epoch 31 / 100, seconds: 188) train loss: 0.000029 validation loss: 0.000563
# (Epoch 32 / 100, seconds: 188) train loss: 0.000029 validation loss: 0.000563
# (Epoch 33 / 100, seconds: 187) train loss: 0.000029 validation loss: 0.000554
# (Epoch 34 / 100, seconds: 187) train loss: 0.000029 validation loss: 0.000554
# (Epoch 35 / 100, seconds: 186) train loss: 0.000029 validation loss: 0.000557
# (Epoch 36 / 100, seconds: 189) train loss: 0.000029 validation loss: 0.000552
# (Epoch 37 / 100, seconds: 189) train loss: 0.000028 validation loss: 0.000552
# (Epoch 38 / 100, seconds: 189) train loss: 0.000028 validation loss: 0.000544
# (Epoch 39 / 100, seconds: 191) train loss: 0.000028 validation loss: 0.000541
# (Epoch 40 / 100, seconds: 189) train loss: 0.000028 validation loss: 0.000538
# (Epoch 41 / 100, seconds: 190) train loss: 0.000028 validation loss: 0.000533
# (Epoch 42 / 100, seconds: 189) train loss: 0.000028 validation loss: 0.000537
# (Epoch 43 / 100, seconds: 189) train loss: 0.000028 validation loss: 0.000525
# (Epoch 44 / 100, seconds: 191) train loss: 0.000027 validation loss: 0.000520
# (Epoch 45 / 100, seconds: 190) train loss: 0.000027 validation loss: 0.000521
# (Epoch 46 / 100, seconds: 188) train loss: 0.000027 validation loss: 0.000521
# (Epoch 47 / 100, seconds: 183) train loss: 0.000027 validation loss: 0.000513
# (Epoch 48 / 100, seconds: 182) train loss: 0.000027 validation loss: 0.000514
# (Epoch 49 / 100, seconds: 183) train loss: 0.000027 validation loss: 0.000510
# (Epoch 50 / 100, seconds: 182) train loss: 0.000027 validation loss: 0.000520
# (Epoch 51 / 100, seconds: 183) train loss: 0.000027 validation loss: 0.000510
# (Epoch 52 / 100, seconds: 183) train loss: 0.000027 validation loss: 0.000511
# (Epoch 53 / 100, seconds: 183) train loss: 0.000027 validation loss: 0.000499
# (Epoch 54 / 100, seconds: 182) train loss: 0.000026 validation loss: 0.000510
# (Epoch 55 / 100, seconds: 183) train loss: 0.000026 validation loss: 0.000507
# (Epoch 56 / 100, seconds: 185) train loss: 0.000026 validation loss: 0.000507
# (Epoch 57 / 100, seconds: 186) train loss: 0.000026 validation loss: 0.000498
# (Epoch 58 / 100, seconds: 186) train loss: 0.000026 validation loss: 0.000501
# (Epoch 59 / 100, seconds: 187) train loss: 0.000026 validation loss: 0.000497
# (Epoch 60 / 100, seconds: 186) train loss: 0.000026 validation loss: 0.000498
# (Epoch 61 / 100, seconds: 186) train loss: 0.000026 validation loss: 0.000508
# (Epoch 62 / 100, seconds: 186) train loss: 0.000026 validation loss: 0.000499
# (Epoch 63 / 100, seconds: 188) train loss: 0.000026 validation loss: 0.000504
# (Epoch 64 / 100, seconds: 187) train loss: 0.000026 validation loss: 0.000495
# (Epoch 65 / 100, seconds: 187) train loss: 0.000025 validation loss: 0.000489
# (Epoch 66 / 100, seconds: 187) train loss: 0.000025 validation loss: 0.000513
# (Epoch 67 / 100, seconds: 187) train loss: 0.000025 validation loss: 0.000484
# (Epoch 68 / 100, seconds: 187) train loss: 0.000025 validation loss: 0.000483
# (Epoch 69 / 100, seconds: 187) train loss: 0.000025 validation loss: 0.000508
# (Epoch 70 / 100, seconds: 187) train loss: 0.000025 validation loss: 0.000474
# (Epoch 71 / 100, seconds: 184) train loss: 0.000025 validation loss: 0.000480
# (Epoch 72 / 100, seconds: 182) train loss: 0.000025 validation loss: 0.000478
# (Epoch 73 / 100, seconds: 183) train loss: 0.000025 validation loss: 0.000474
# (Epoch 74 / 100, seconds: 181) train loss: 0.000025 validation loss: 0.000485
# (Epoch 75 / 100, seconds: 182) train loss: 0.000025 validation loss: 0.000474
# (Epoch 76 / 100, seconds: 182) train loss: 0.000025 validation loss: 0.000472
# (Epoch 77 / 100, seconds: 182) train loss: 0.000025 validation loss: 0.000471
# (Epoch 78 / 100, seconds: 184) train loss: 0.000025 validation loss: 0.000465
# (Epoch 79 / 100, seconds: 186) train loss: 0.000025 validation loss: 0.000475
# (Epoch 80 / 100, seconds: 186) train loss: 0.000024 validation loss: 0.000471
# (Epoch 81 / 100, seconds: 186) train loss: 0.000024 validation loss: 0.000467
# (Epoch 82 / 100, seconds: 186) train loss: 0.000024 validation loss: 0.000466
# (Epoch 83 / 100, seconds: 187) train loss: 0.000024 validation loss: 0.000478
# (Epoch 84 / 100, seconds: 187) train loss: 0.000024 validation loss: 0.000466
# (Epoch 85 / 100, seconds: 187) train loss: 0.000024 validation loss: 0.000461
# (Epoch 86 / 100, seconds: 188) train loss: 0.000024 validation loss: 0.000502
# (Epoch 87 / 100, seconds: 189) train loss: 0.000024 validation loss: 0.000467
# (Epoch 88 / 100, seconds: 187) train loss: 0.000024 validation loss: 0.000460
# (Epoch 89 / 100, seconds: 187) train loss: 0.000024 validation loss: 0.000462
# (Epoch 90 / 100, seconds: 187) train loss: 0.000024 validation loss: 0.000466
# (Epoch 91 / 100, seconds: 188) train loss: 0.000024 validation loss: 0.000475
# (Epoch 92 / 100, seconds: 188) train loss: 0.000024 validation loss: 0.000489
# (Epoch 93 / 100, seconds: 188) train loss: 0.000024 validation loss: 0.000461
# (Epoch 94 / 100, seconds: 187) train loss: 0.000024 validation loss: 0.000461
# (Epoch 95 / 100, seconds: 187) train loss: 0.000024 validation loss: 0.000458
# (Epoch 96 / 100, seconds: 188) train loss: 0.000024 validation loss: 0.000473
# (Epoch 97 / 100, seconds: 188) train loss: 0.000024 validation loss: 0.000463
# (Epoch 98 / 100, seconds: 188) train loss: 0.000024 validation loss: 0.000490
# (Epoch 99 / 100, seconds: 188) train loss: 0.000024 validation loss: 0.000503
# (Epoch 100 / 100, seconds: 188) train loss: 0.000024 validation loss: 0.000456

# %%
phase_check_rungekutta(trained_model_runge_2)

# %%
trained_model_runge_3 = train_rungekutta(BIFURCATION_DATASET, 150, 128)
torch.save(trained_model_runge_3.state_dict(),'./rungekuttamodel_150epoch.pt')
# Out:
# BIFURCATION_DATASET.shape torch.Size([645605, 5])
# (Epoch 1 / 150, seconds: 116) train loss: 0.000105 validation loss: 0.000900
# (Epoch 2 / 150, seconds: 116) train loss: 0.000044 validation loss: 0.000848
# (Epoch 3 / 150, seconds: 115) train loss: 0.000042 validation loss: 0.000810
# (Epoch 4 / 150, seconds: 116) train loss: 0.000040 validation loss: 0.000778
# (Epoch 5 / 150, seconds: 115) train loss: 0.000038 validation loss: 0.000745
# (Epoch 6 / 150, seconds: 115) train loss: 0.000037 validation loss: 0.000722
# (Epoch 7 / 150, seconds: 116) train loss: 0.000037 validation loss: 0.000702
# (Epoch 8 / 150, seconds: 116) train loss: 0.000036 validation loss: 0.000690
# (Epoch 9 / 150, seconds: 116) train loss: 0.000035 validation loss: 0.000683
# (Epoch 10 / 150, seconds: 116) train loss: 0.000035 validation loss: 0.000679
# (Epoch 11 / 150, seconds: 116) train loss: 0.000034 validation loss: 0.000674
# (Epoch 12 / 150, seconds: 116) train loss: 0.000034 validation loss: 0.000668
# (Epoch 13 / 150, seconds: 116) train loss: 0.000033 validation loss: 0.000655
# (Epoch 14 / 150, seconds: 116) train loss: 0.000033 validation loss: 0.000651
# (Epoch 15 / 150, seconds: 116) train loss: 0.000033 validation loss: 0.000643
# (Epoch 16 / 150, seconds: 116) train loss: 0.000032 validation loss: 0.000636
# (Epoch 17 / 150, seconds: 116) train loss: 0.000032 validation loss: 0.000631
# (Epoch 18 / 150, seconds: 116) train loss: 0.000032 validation loss: 0.000624
# (Epoch 19 / 150, seconds: 116) train loss: 0.000031 validation loss: 0.000614
# (Epoch 20 / 150, seconds: 116) train loss: 0.000031 validation loss: 0.000608
# (Epoch 21 / 150, seconds: 116) train loss: 0.000031 validation loss: 0.000601
# (Epoch 22 / 150, seconds: 116) train loss: 0.000031 validation loss: 0.000599
# (Epoch 23 / 150, seconds: 116) train loss: 0.000030 validation loss: 0.000593
# (Epoch 24 / 150, seconds: 116) train loss: 0.000030 validation loss: 0.000586
# (Epoch 25 / 150, seconds: 116) train loss: 0.000030 validation loss: 0.000574
# (Epoch 26 / 150, seconds: 116) train loss: 0.000030 validation loss: 0.000580
# (Epoch 27 / 150, seconds: 116) train loss: 0.000029 validation loss: 0.000567
# (Epoch 28 / 150, seconds: 116) train loss: 0.000029 validation loss: 0.000564
# (Epoch 29 / 150, seconds: 116) train loss: 0.000029 validation loss: 0.000559
# (Epoch 30 / 150, seconds: 115) train loss: 0.000029 validation loss: 0.000561
# (Epoch 31 / 150, seconds: 116) train loss: 0.000028 validation loss: 0.000566
# (Epoch 32 / 150, seconds: 116) train loss: 0.000028 validation loss: 0.000540
# (Epoch 33 / 150, seconds: 116) train loss: 0.000028 validation loss: 0.000575
# (Epoch 34 / 150, seconds: 116) train loss: 0.000028 validation loss: 0.000554
# (Epoch 35 / 150, seconds: 116) train loss: 0.000028 validation loss: 0.000524
# (Epoch 36 / 150, seconds: 116) train loss: 0.000028 validation loss: 0.000548
# (Epoch 37 / 150, seconds: 116) train loss: 0.000027 validation loss: 0.000519
# (Epoch 38 / 150, seconds: 116) train loss: 0.000027 validation loss: 0.000526
# (Epoch 39 / 150, seconds: 116) train loss: 0.000027 validation loss: 0.000550
# (Epoch 40 / 150, seconds: 116) train loss: 0.000027 validation loss: 0.000525
# (Epoch 41 / 150, seconds: 116) train loss: 0.000027 validation loss: 0.000503
# (Epoch 42 / 150, seconds: 116) train loss: 0.000027 validation loss: 0.000537
# (Epoch 43 / 150, seconds: 116) train loss: 0.000027 validation loss: 0.000498
# (Epoch 44 / 150, seconds: 116) train loss: 0.000027 validation loss: 0.000495
# (Epoch 45 / 150, seconds: 115) train loss: 0.000026 validation loss: 0.000495
# (Epoch 46 / 150, seconds: 116) train loss: 0.000026 validation loss: 0.000519
# (Epoch 47 / 150, seconds: 116) train loss: 0.000026 validation loss: 0.000498
# (Epoch 48 / 150, seconds: 115) train loss: 0.000026 validation loss: 0.000488
# (Epoch 49 / 150, seconds: 116) train loss: 0.000026 validation loss: 0.000488
# (Epoch 50 / 150, seconds: 115) train loss: 0.000026 validation loss: 0.000499
# (Epoch 51 / 150, seconds: 115) train loss: 0.000026 validation loss: 0.000486
# (Epoch 52 / 150, seconds: 115) train loss: 0.000026 validation loss: 0.000481
# (Epoch 53 / 150, seconds: 115) train loss: 0.000026 validation loss: 0.000482
# (Epoch 54 / 150, seconds: 115) train loss: 0.000026 validation loss: 0.000487
# (Epoch 55 / 150, seconds: 116) train loss: 0.000026 validation loss: 0.000478
# (Epoch 56 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000503
# (Epoch 57 / 150, seconds: 117) train loss: 0.000025 validation loss: 0.000474
# (Epoch 58 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000476
# (Epoch 59 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000472
# (Epoch 60 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000474
# (Epoch 61 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000468
# (Epoch 62 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000484
# (Epoch 63 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000471
# (Epoch 64 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000491
# (Epoch 65 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000474
# (Epoch 66 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000468
# (Epoch 67 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000460
# (Epoch 68 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000471
# (Epoch 69 / 150, seconds: 115) train loss: 0.000025 validation loss: 0.000572
# (Epoch 70 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000473
# (Epoch 71 / 150, seconds: 116) train loss: 0.000025 validation loss: 0.000464
# (Epoch 72 / 150, seconds: 116) train loss: 0.000024 validation loss: 0.000460
# (Epoch 73 / 150, seconds: 117) train loss: 0.000024 validation loss: 0.000458
# (Epoch 74 / 150, seconds: 117) train loss: 0.000024 validation loss: 0.000465
# (Epoch 75 / 150, seconds: 117) train loss: 0.000024 validation loss: 0.000453
# (Epoch 76 / 150, seconds: 117) train loss: 0.000024 validation loss: 0.000455
# (Epoch 77 / 150, seconds: 117) train loss: 0.000024 validation loss: 0.000456
# (Epoch 78 / 150, seconds: 117) train loss: 0.000024 validation loss: 0.000455
# (Epoch 79 / 150, seconds: 117) train loss: 0.000024 validation loss: 0.000452
# (Epoch 80 / 150, seconds: 116) train loss: 0.000024 validation loss: 0.000455
# (Epoch 81 / 150, seconds: 117) train loss: 0.000024 validation loss: 0.000506
# (Epoch 82 / 150, seconds: 116) train loss: 0.000024 validation loss: 0.000452
# (Epoch 83 / 150, seconds: 117) train loss: 0.000024 validation loss: 0.000480
# (Epoch 84 / 150, seconds: 117) train loss: 0.000024 validation loss: 0.000556
# (Epoch 85 / 150, seconds: 116) train loss: 0.000024 validation loss: 0.000468
# (Epoch 86 / 150, seconds: 117) train loss: 0.000024 validation loss: 0.000450
# (Epoch 87 / 150, seconds: 116) train loss: 0.000024 validation loss: 0.000470
# (Epoch 88 / 150, seconds: 117) train loss: 0.000024 validation loss: 0.000458
# (Epoch 89 / 150, seconds: 117) train loss: 0.000024 validation loss: 0.000447
# (Epoch 90 / 150, seconds: 117) train loss: 0.000023 validation loss: 0.000444
# (Epoch 91 / 150, seconds: 118) train loss: 0.000023 validation loss: 0.000446
# (Epoch 92 / 150, seconds: 117) train loss: 0.000023 validation loss: 0.000443
# (Epoch 93 / 150, seconds: 117) train loss: 0.000023 validation loss: 0.000471
# (Epoch 94 / 150, seconds: 118) train loss: 0.000023 validation loss: 0.000467
# (Epoch 95 / 150, seconds: 117) train loss: 0.000023 validation loss: 0.000464
# (Epoch 96 / 150, seconds: 118) train loss: 0.000023 validation loss: 0.000443
# (Epoch 97 / 150, seconds: 118) train loss: 0.000023 validation loss: 0.000445
# (Epoch 98 / 150, seconds: 118) train loss: 0.000023 validation loss: 0.000435
# (Epoch 99 / 150, seconds: 118) train loss: 0.000023 validation loss: 0.000437
# (Epoch 100 / 150, seconds: 117) train loss: 0.000023 validation loss: 0.000440
# (Epoch 101 / 150, seconds: 116) train loss: 0.000023 validation loss: 0.000493
# (Epoch 102 / 150, seconds: 117) train loss: 0.000023 validation loss: 0.000447
# (Epoch 103 / 150, seconds: 116) train loss: 0.000023 validation loss: 0.000440
# (Epoch 104 / 150, seconds: 117) train loss: 0.000023 validation loss: 0.000437
# (Epoch 105 / 150, seconds: 116) train loss: 0.000023 validation loss: 0.000433
# (Epoch 106 / 150, seconds: 116) train loss: 0.000023 validation loss: 0.000493
# (Epoch 107 / 150, seconds: 116) train loss: 0.000023 validation loss: 0.000445
# (Epoch 108 / 150, seconds: 116) train loss: 0.000023 validation loss: 0.000442
# (Epoch 109 / 150, seconds: 117) train loss: 0.000023 validation loss: 0.000451
# (Epoch 110 / 150, seconds: 116) train loss: 0.000023 validation loss: 0.000434
# (Epoch 111 / 150, seconds: 116) train loss: 0.000023 validation loss: 0.000433
# (Epoch 112 / 150, seconds: 116) train loss: 0.000023 validation loss: 0.000437
# (Epoch 113 / 150, seconds: 116) train loss: 0.000023 validation loss: 0.000448
# (Epoch 114 / 150, seconds: 116) train loss: 0.000023 validation loss: 0.000478
# (Epoch 115 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000447
# (Epoch 116 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000453
# (Epoch 117 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000451
# (Epoch 118 / 150, seconds: 116) train loss: 0.000022 validation loss: 0.000557
# (Epoch 119 / 150, seconds: 115) train loss: 0.000023 validation loss: 0.000433
# (Epoch 120 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000444
# (Epoch 121 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000456
# (Epoch 122 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000433
# (Epoch 123 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000440
# (Epoch 124 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000446
# (Epoch 125 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000435
# (Epoch 126 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000432
# (Epoch 127 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000433
# (Epoch 128 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000430
# (Epoch 129 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000446
# (Epoch 130 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000419
# (Epoch 131 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000429
# (Epoch 132 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000442
# (Epoch 133 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000432
# (Epoch 134 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000425
# (Epoch 135 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000449
# (Epoch 136 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000453
# (Epoch 137 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000449
# (Epoch 138 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000434
# (Epoch 139 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000424
# (Epoch 140 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000451
# (Epoch 141 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000418
# (Epoch 142 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000435
# (Epoch 143 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000426
# (Epoch 144 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000426
# (Epoch 145 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000432
# (Epoch 146 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000440
# (Epoch 147 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000451
# (Epoch 148 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000417
# (Epoch 149 / 150, seconds: 115) train loss: 0.000022 validation loss: 0.000433
# (Epoch 150 / 150, seconds: 114) train loss: 0.000022 validation loss: 0.000439

# %%
phase_check_rungekutta(trained_model_runge_3)

# %% [markdown]
# # Train Euler

# %%
trained_model_euler = train_euler(BIFURCATION_DATASET, 50, 128)

# %%
phase_check(trained_model_euler)

# %%
torch.save(trained_model_euler.state_dict(),'./eulermodel.pt')

# %%
trained_model_euler_2 = train_euler(BIFURCATION_DATASET, 100, 128)
# Out:
# BIFURCATION_DATASET.shape torch.Size([645605, 5])
# (Epoch 1 / 100, seconds: 85) train loss: 0.000105 validation loss: 0.000853
# (Epoch 2 / 100, seconds: 85) train loss: 0.000044 validation loss: 0.000800
# (Epoch 3 / 100, seconds: 85) train loss: 0.000041 validation loss: 0.000776
# (Epoch 4 / 100, seconds: 84) train loss: 0.000039 validation loss: 0.000744
# (Epoch 5 / 100, seconds: 84) train loss: 0.000038 validation loss: 0.000721
# (Epoch 6 / 100, seconds: 84) train loss: 0.000037 validation loss: 0.000709
# (Epoch 7 / 100, seconds: 85) train loss: 0.000036 validation loss: 0.000699
# (Epoch 8 / 100, seconds: 84) train loss: 0.000035 validation loss: 0.000690
# (Epoch 9 / 100, seconds: 85) train loss: 0.000034 validation loss: 0.000679
# (Epoch 10 / 100, seconds: 84) train loss: 0.000034 validation loss: 0.000666
# (Epoch 11 / 100, seconds: 85) train loss: 0.000033 validation loss: 0.000656
# (Epoch 12 / 100, seconds: 85) train loss: 0.000033 validation loss: 0.000644
# (Epoch 13 / 100, seconds: 84) train loss: 0.000033 validation loss: 0.000634
# (Epoch 14 / 100, seconds: 85) train loss: 0.000032 validation loss: 0.000624
# (Epoch 15 / 100, seconds: 84) train loss: 0.000032 validation loss: 0.000614
# (Epoch 16 / 100, seconds: 83) train loss: 0.000032 validation loss: 0.000606
# (Epoch 17 / 100, seconds: 83) train loss: 0.000031 validation loss: 0.000601
# (Epoch 18 / 100, seconds: 84) train loss: 0.000031 validation loss: 0.000591
# (Epoch 19 / 100, seconds: 84) train loss: 0.000031 validation loss: 0.000586
# (Epoch 20 / 100, seconds: 84) train loss: 0.000030 validation loss: 0.000579
# (Epoch 21 / 100, seconds: 84) train loss: 0.000030 validation loss: 0.000571
# (Epoch 22 / 100, seconds: 84) train loss: 0.000030 validation loss: 0.000564
# (Epoch 23 / 100, seconds: 84) train loss: 0.000029 validation loss: 0.000560
# (Epoch 24 / 100, seconds: 84) train loss: 0.000029 validation loss: 0.000552
# (Epoch 25 / 100, seconds: 84) train loss: 0.000029 validation loss: 0.000545
# (Epoch 26 / 100, seconds: 84) train loss: 0.000029 validation loss: 0.000544
# (Epoch 27 / 100, seconds: 84) train loss: 0.000028 validation loss: 0.000540
# (Epoch 28 / 100, seconds: 84) train loss: 0.000028 validation loss: 0.000535
# (Epoch 29 / 100, seconds: 85) train loss: 0.000028 validation loss: 0.000531
# (Epoch 30 / 100, seconds: 84) train loss: 0.000028 validation loss: 0.000525
# (Epoch 31 / 100, seconds: 84) train loss: 0.000028 validation loss: 0.000524
# (Epoch 32 / 100, seconds: 84) train loss: 0.000027 validation loss: 0.000518
# (Epoch 33 / 100, seconds: 84) train loss: 0.000027 validation loss: 0.000514
# (Epoch 34 / 100, seconds: 84) train loss: 0.000027 validation loss: 0.000513
# (Epoch 35 / 100, seconds: 84) train loss: 0.000027 validation loss: 0.000507
# (Epoch 36 / 100, seconds: 84) train loss: 0.000027 validation loss: 0.000501
# (Epoch 37 / 100, seconds: 84) train loss: 0.000026 validation loss: 0.000500
# (Epoch 38 / 100, seconds: 84) train loss: 0.000026 validation loss: 0.000496
# (Epoch 39 / 100, seconds: 84) train loss: 0.000026 validation loss: 0.000495
# (Epoch 40 / 100, seconds: 84) train loss: 0.000026 validation loss: 0.000488
# (Epoch 41 / 100, seconds: 84) train loss: 0.000026 validation loss: 0.000488
# (Epoch 42 / 100, seconds: 84) train loss: 0.000026 validation loss: 0.000481
# (Epoch 43 / 100, seconds: 84) train loss: 0.000026 validation loss: 0.000481
# (Epoch 44 / 100, seconds: 84) train loss: 0.000025 validation loss: 0.000477
# (Epoch 45 / 100, seconds: 84) train loss: 0.000025 validation loss: 0.000475
# (Epoch 46 / 100, seconds: 84) train loss: 0.000025 validation loss: 0.000471
# (Epoch 47 / 100, seconds: 84) train loss: 0.000025 validation loss: 0.000473
# (Epoch 48 / 100, seconds: 84) train loss: 0.000025 validation loss: 0.000470
# (Epoch 49 / 100, seconds: 84) train loss: 0.000025 validation loss: 0.000467
# (Epoch 50 / 100, seconds: 83) train loss: 0.000025 validation loss: 0.000464
# (Epoch 51 / 100, seconds: 84) train loss: 0.000025 validation loss: 0.000465
# (Epoch 52 / 100, seconds: 83) train loss: 0.000024 validation loss: 0.000460
# (Epoch 53 / 100, seconds: 83) train loss: 0.000024 validation loss: 0.000458
# (Epoch 54 / 100, seconds: 84) train loss: 0.000024 validation loss: 0.000457
# (Epoch 55 / 100, seconds: 83) train loss: 0.000024 validation loss: 0.000457
# (Epoch 56 / 100, seconds: 83) train loss: 0.000024 validation loss: 0.000458
# (Epoch 57 / 100, seconds: 83) train loss: 0.000024 validation loss: 0.000458
# (Epoch 58 / 100, seconds: 83) train loss: 0.000024 validation loss: 0.000454
# (Epoch 59 / 100, seconds: 83) train loss: 0.000024 validation loss: 0.000451
# (Epoch 60 / 100, seconds: 83) train loss: 0.000024 validation loss: 0.000456
# (Epoch 61 / 100, seconds: 83) train loss: 0.000024 validation loss: 0.000449
# (Epoch 62 / 100, seconds: 83) train loss: 0.000024 validation loss: 0.000448
# (Epoch 63 / 100, seconds: 83) train loss: 0.000024 validation loss: 0.000448
# (Epoch 64 / 100, seconds: 83) train loss: 0.000023 validation loss: 0.000448
# (Epoch 65 / 100, seconds: 83) train loss: 0.000023 validation loss: 0.000445
# (Epoch 66 / 100, seconds: 83) train loss: 0.000023 validation loss: 0.000444
# (Epoch 67 / 100, seconds: 83) train loss: 0.000023 validation loss: 0.000445
# (Epoch 68 / 100, seconds: 84) train loss: 0.000023 validation loss: 0.000443
# (Epoch 69 / 100, seconds: 84) train loss: 0.000023 validation loss: 0.000440
# (Epoch 70 / 100, seconds: 84) train loss: 0.000023 validation loss: 0.000438
# (Epoch 71 / 100, seconds: 84) train loss: 0.000023 validation loss: 0.000439
# (Epoch 72 / 100, seconds: 84) train loss: 0.000023 validation loss: 0.000437
# (Epoch 73 / 100, seconds: 85) train loss: 0.000023 validation loss: 0.000438
# (Epoch 74 / 100, seconds: 84) train loss: 0.000023 validation loss: 0.000435
# (Epoch 75 / 100, seconds: 84) train loss: 0.000023 validation loss: 0.000434
# (Epoch 76 / 100, seconds: 85) train loss: 0.000023 validation loss: 0.000431
# (Epoch 77 / 100, seconds: 85) train loss: 0.000023 validation loss: 0.000433
# (Epoch 78 / 100, seconds: 84) train loss: 0.000023 validation loss: 0.000431
# (Epoch 79 / 100, seconds: 84) train loss: 0.000023 validation loss: 0.000432
# (Epoch 80 / 100, seconds: 84) train loss: 0.000023 validation loss: 0.000430
# (Epoch 81 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000429
# (Epoch 82 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000427
# (Epoch 83 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000428
# (Epoch 84 / 100, seconds: 85) train loss: 0.000022 validation loss: 0.000427
# (Epoch 85 / 100, seconds: 85) train loss: 0.000022 validation loss: 0.000425
# (Epoch 86 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000426
# (Epoch 87 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000423
# (Epoch 88 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000424
# (Epoch 89 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000423
# (Epoch 90 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000423
# (Epoch 91 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000420
# (Epoch 92 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000422
# (Epoch 93 / 100, seconds: 83) train loss: 0.000022 validation loss: 0.000421
# (Epoch 94 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000420
# (Epoch 95 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000418
# (Epoch 96 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000417
# (Epoch 97 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000419
# (Epoch 98 / 100, seconds: 84) train loss: 0.000022 validation loss: 0.000420
# (Epoch 99 / 100, seconds: 85) train loss: 0.000022 validation loss: 0.000416
# (Epoch 100 / 100, seconds: 84) train loss: 0.000021 validation loss: 0.000415
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-548b92f8dcf6> in <module>()
#       1 trained_model_euler_2 = train_euler(BIFURCATION_DATASET, 100, 128)
# ----> 2 torch.save(trained_model_euler.state_dict(),'./eulermodel_100epoch.pt')
#
# NameError: name 'trained_model_euler' is not defined

# %%
torch.save(trained_model_euler_2.state_dict(),'./eulermodel_100epoch.pt')

# %%
phase_check(trained_model_euler_2)

# %%
trained_model_euler_3 = train_euler(BIFURCATION_DATASET, 150, 128)
torch.save(trained_model_euler_3.state_dict(),'./eulermodel_150epoch.pt')
# Out:
# BIFURCATION_DATASET.shape torch.Size([645605, 5])
# (Epoch 1 / 150, seconds: 85) train loss: 0.000106 validation loss: 0.000831
# (Epoch 2 / 150, seconds: 84) train loss: 0.000044 validation loss: 0.000779
# (Epoch 3 / 150, seconds: 85) train loss: 0.000040 validation loss: 0.000742
# (Epoch 4 / 150, seconds: 84) train loss: 0.000038 validation loss: 0.000733
# (Epoch 5 / 150, seconds: 84) train loss: 0.000037 validation loss: 0.000722
# (Epoch 6 / 150, seconds: 84) train loss: 0.000036 validation loss: 0.000707
# (Epoch 7 / 150, seconds: 84) train loss: 0.000036 validation loss: 0.000696
# (Epoch 8 / 150, seconds: 84) train loss: 0.000035 validation loss: 0.000691
# (Epoch 9 / 150, seconds: 84) train loss: 0.000034 validation loss: 0.000682
# (Epoch 10 / 150, seconds: 85) train loss: 0.000034 validation loss: 0.000669
# (Epoch 11 / 150, seconds: 85) train loss: 0.000034 validation loss: 0.000660
# (Epoch 12 / 150, seconds: 84) train loss: 0.000033 validation loss: 0.000655
# (Epoch 13 / 150, seconds: 84) train loss: 0.000033 validation loss: 0.000647
# (Epoch 14 / 150, seconds: 85) train loss: 0.000032 validation loss: 0.000639
# (Epoch 15 / 150, seconds: 85) train loss: 0.000032 validation loss: 0.000632
# (Epoch 16 / 150, seconds: 85) train loss: 0.000032 validation loss: 0.000626
# (Epoch 17 / 150, seconds: 85) train loss: 0.000031 validation loss: 0.000621
# (Epoch 18 / 150, seconds: 84) train loss: 0.000031 validation loss: 0.000614
# (Epoch 19 / 150, seconds: 84) train loss: 0.000031 validation loss: 0.000607
# (Epoch 20 / 150, seconds: 84) train loss: 0.000031 validation loss: 0.000601
# (Epoch 21 / 150, seconds: 84) train loss: 0.000030 validation loss: 0.000591
# (Epoch 22 / 150, seconds: 85) train loss: 0.000030 validation loss: 0.000584
# (Epoch 23 / 150, seconds: 84) train loss: 0.000030 validation loss: 0.000576
# (Epoch 24 / 150, seconds: 85) train loss: 0.000030 validation loss: 0.000571
# (Epoch 25 / 150, seconds: 85) train loss: 0.000029 validation loss: 0.000567
# (Epoch 26 / 150, seconds: 85) train loss: 0.000029 validation loss: 0.000560
# (Epoch 27 / 150, seconds: 85) train loss: 0.000029 validation loss: 0.000555
# (Epoch 28 / 150, seconds: 86) train loss: 0.000029 validation loss: 0.000553
# (Epoch 29 / 150, seconds: 85) train loss: 0.000028 validation loss: 0.000553
# (Epoch 30 / 150, seconds: 85) train loss: 0.000028 validation loss: 0.000546
# (Epoch 31 / 150, seconds: 84) train loss: 0.000028 validation loss: 0.000543
# (Epoch 32 / 150, seconds: 84) train loss: 0.000028 validation loss: 0.000537
# (Epoch 33 / 150, seconds: 84) train loss: 0.000028 validation loss: 0.000536
# (Epoch 34 / 150, seconds: 84) train loss: 0.000028 validation loss: 0.000532
# (Epoch 35 / 150, seconds: 84) train loss: 0.000027 validation loss: 0.000526
# (Epoch 36 / 150, seconds: 84) train loss: 0.000027 validation loss: 0.000525
# (Epoch 37 / 150, seconds: 84) train loss: 0.000027 validation loss: 0.000523
# (Epoch 38 / 150, seconds: 84) train loss: 0.000027 validation loss: 0.000516
# (Epoch 39 / 150, seconds: 85) train loss: 0.000027 validation loss: 0.000516
# (Epoch 40 / 150, seconds: 84) train loss: 0.000026 validation loss: 0.000510
# (Epoch 41 / 150, seconds: 84) train loss: 0.000026 validation loss: 0.000508
# (Epoch 42 / 150, seconds: 84) train loss: 0.000026 validation loss: 0.000503
# (Epoch 43 / 150, seconds: 84) train loss: 0.000026 validation loss: 0.000495
# (Epoch 44 / 150, seconds: 84) train loss: 0.000026 validation loss: 0.000495
# (Epoch 45 / 150, seconds: 84) train loss: 0.000026 validation loss: 0.000489
# (Epoch 46 / 150, seconds: 84) train loss: 0.000025 validation loss: 0.000486
# (Epoch 47 / 150, seconds: 85) train loss: 0.000025 validation loss: 0.000483
# (Epoch 48 / 150, seconds: 84) train loss: 0.000025 validation loss: 0.000480
# (Epoch 49 / 150, seconds: 85) train loss: 0.000025 validation loss: 0.000477
# (Epoch 50 / 150, seconds: 85) train loss: 0.000025 validation loss: 0.000477
# (Epoch 51 / 150, seconds: 84) train loss: 0.000025 validation loss: 0.000468
# (Epoch 52 / 150, seconds: 84) train loss: 0.000025 validation loss: 0.000469
# (Epoch 53 / 150, seconds: 84) train loss: 0.000025 validation loss: 0.000469
# (Epoch 54 / 150, seconds: 85) train loss: 0.000025 validation loss: 0.000466
# (Epoch 55 / 150, seconds: 85) train loss: 0.000024 validation loss: 0.000464
# (Epoch 56 / 150, seconds: 85) train loss: 0.000024 validation loss: 0.000464
# (Epoch 57 / 150, seconds: 85) train loss: 0.000024 validation loss: 0.000462
# (Epoch 58 / 150, seconds: 85) train loss: 0.000024 validation loss: 0.000455
# (Epoch 59 / 150, seconds: 85) train loss: 0.000024 validation loss: 0.000455
# (Epoch 60 / 150, seconds: 85) train loss: 0.000024 validation loss: 0.000456
# (Epoch 61 / 150, seconds: 85) train loss: 0.000024 validation loss: 0.000453
# (Epoch 62 / 150, seconds: 85) train loss: 0.000024 validation loss: 0.000449
# (Epoch 63 / 150, seconds: 85) train loss: 0.000024 validation loss: 0.000451
# (Epoch 64 / 150, seconds: 84) train loss: 0.000024 validation loss: 0.000450
# (Epoch 65 / 150, seconds: 85) train loss: 0.000024 validation loss: 0.000444
# (Epoch 66 / 150, seconds: 84) train loss: 0.000023 validation loss: 0.000445
# (Epoch 67 / 150, seconds: 84) train loss: 0.000023 validation loss: 0.000444
# (Epoch 68 / 150, seconds: 85) train loss: 0.000023 validation loss: 0.000441
# (Epoch 69 / 150, seconds: 84) train loss: 0.000023 validation loss: 0.000441
# (Epoch 70 / 150, seconds: 84) train loss: 0.000023 validation loss: 0.000442
# (Epoch 71 / 150, seconds: 84) train loss: 0.000023 validation loss: 0.000442
# (Epoch 72 / 150, seconds: 84) train loss: 0.000023 validation loss: 0.000440
# (Epoch 73 / 150, seconds: 84) train loss: 0.000023 validation loss: 0.000439
# (Epoch 74 / 150, seconds: 84) train loss: 0.000023 validation loss: 0.000439
# (Epoch 75 / 150, seconds: 85) train loss: 0.000023 validation loss: 0.000439
# (Epoch 76 / 150, seconds: 85) train loss: 0.000023 validation loss: 0.000436
# (Epoch 77 / 150, seconds: 84) train loss: 0.000023 validation loss: 0.000438
# (Epoch 78 / 150, seconds: 84) train loss: 0.000023 validation loss: 0.000435
# (Epoch 79 / 150, seconds: 84) train loss: 0.000023 validation loss: 0.000435
# (Epoch 80 / 150, seconds: 83) train loss: 0.000022 validation loss: 0.000434
# (Epoch 81 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000436
# (Epoch 82 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000433
# (Epoch 83 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000430
# (Epoch 84 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000428
# (Epoch 85 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000428
# (Epoch 86 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000428
# (Epoch 87 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000425
# (Epoch 88 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000431
# (Epoch 89 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000429
# (Epoch 90 / 150, seconds: 85) train loss: 0.000022 validation loss: 0.000431
# (Epoch 91 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000429
# (Epoch 92 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000427
# (Epoch 93 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000427
# (Epoch 94 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000425
# (Epoch 95 / 150, seconds: 83) train loss: 0.000022 validation loss: 0.000422
# (Epoch 96 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000425
# (Epoch 97 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000421
# (Epoch 98 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000422
# (Epoch 99 / 150, seconds: 84) train loss: 0.000022 validation loss: 0.000420
# (Epoch 100 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000423
# (Epoch 101 / 150, seconds: 84) train loss: 0.000021 validation loss: 0.000421
# (Epoch 102 / 150, seconds: 84) train loss: 0.000021 validation loss: 0.000420
# (Epoch 103 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000420
# (Epoch 104 / 150, seconds: 84) train loss: 0.000021 validation loss: 0.000417
# (Epoch 105 / 150, seconds: 84) train loss: 0.000021 validation loss: 0.000415
# (Epoch 106 / 150, seconds: 84) train loss: 0.000021 validation loss: 0.000422
# (Epoch 107 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000417
# (Epoch 108 / 150, seconds: 84) train loss: 0.000021 validation loss: 0.000417
# (Epoch 109 / 150, seconds: 84) train loss: 0.000021 validation loss: 0.000414
# (Epoch 110 / 150, seconds: 84) train loss: 0.000021 validation loss: 0.000412
# (Epoch 111 / 150, seconds: 84) train loss: 0.000021 validation loss: 0.000412
# (Epoch 112 / 150, seconds: 84) train loss: 0.000021 validation loss: 0.000410
# (Epoch 113 / 150, seconds: 84) train loss: 0.000021 validation loss: 0.000410
# (Epoch 114 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000413
# (Epoch 115 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000406
# (Epoch 116 / 150, seconds: 84) train loss: 0.000021 validation loss: 0.000410
# (Epoch 117 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000410
# (Epoch 118 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000406
# (Epoch 119 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000408
# (Epoch 120 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000407
# (Epoch 121 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000408
# (Epoch 122 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000404
# (Epoch 123 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000414
# (Epoch 124 / 150, seconds: 84) train loss: 0.000021 validation loss: 0.000402
# (Epoch 125 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000403
# (Epoch 126 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000406
# (Epoch 127 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000399
# (Epoch 128 / 150, seconds: 82) train loss: 0.000021 validation loss: 0.000401
# (Epoch 129 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000403
# (Epoch 130 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000402
# (Epoch 131 / 150, seconds: 83) train loss: 0.000021 validation loss: 0.000406
# (Epoch 132 / 150, seconds: 84) train loss: 0.000020 validation loss: 0.000403
# (Epoch 133 / 150, seconds: 84) train loss: 0.000020 validation loss: 0.000403
# (Epoch 134 / 150, seconds: 83) train loss: 0.000020 validation loss: 0.000403
# (Epoch 135 / 150, seconds: 83) train loss: 0.000020 validation loss: 0.000402
# (Epoch 136 / 150, seconds: 83) train loss: 0.000020 validation loss: 0.000399
# (Epoch 137 / 150, seconds: 83) train loss: 0.000020 validation loss: 0.000404
# (Epoch 138 / 150, seconds: 84) train loss: 0.000020 validation loss: 0.000403
# (Epoch 139 / 150, seconds: 83) train loss: 0.000020 validation loss: 0.000400
# (Epoch 140 / 150, seconds: 83) train loss: 0.000020 validation loss: 0.000401
# (Epoch 141 / 150, seconds: 84) train loss: 0.000020 validation loss: 0.000400
# (Epoch 142 / 150, seconds: 84) train loss: 0.000020 validation loss: 0.000398
# (Epoch 143 / 150, seconds: 83) train loss: 0.000020 validation loss: 0.000397
# (Epoch 144 / 150, seconds: 83) train loss: 0.000020 validation loss: 0.000394
# (Epoch 145 / 150, seconds: 84) train loss: 0.000020 validation loss: 0.000392
# (Epoch 146 / 150, seconds: 84) train loss: 0.000020 validation loss: 0.000395
# (Epoch 147 / 150, seconds: 83) train loss: 0.000020 validation loss: 0.000399
# (Epoch 148 / 150, seconds: 83) train loss: 0.000020 validation loss: 0.000394
# (Epoch 149 / 150, seconds: 84) train loss: 0.000020 validation loss: 0.000393
# (Epoch 150 / 150, seconds: 83) train loss: 0.000020 validation loss: 0.000400

# %%
phase_check(trained_model_euler_3)

# %% [markdown]
# <img width="800" src="https://drive.google.com/uc?export=view&id=18_ENcBvsKo2FYW1OIYws_bI_aD3LcbHx" />
